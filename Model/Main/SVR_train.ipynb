# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.experimental import enable_halving_search_cv  # noqa
from sklearn.model_selection import HalvingGridSearchCV
import joblib

# %%
df = pd.read_csv("D:\Project\Car-Evaluation\Dataset\Final\Remove-noise-not-outlier-and-fill-null.csv")

# %%
# Save'price_in_billion' individually
price_column = df['price_in_billion']
df = df.drop(['price_in_billion','ad_id','brand','url','grade','condition','price'], axis=1)

# Define columns that need encoded and scaled
columns_for_encoding = ['origin','car_model','exterior_color','interior_color','engine','transmission','drive_type','car_name']
columns_for_scaling = ['num_of_doors','seating_capacity','engine_capacity','fuel_consumption','mileage','year_of_manufacture']

# Define the preprocessing steps for numerical features
numerical_transformer = StandardScaler()

# Define the preprocessing steps for categorical features
categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(sparse_output=False)),
    ('svd', TruncatedSVD(n_components= 500, random_state=42))
])

# Combine preprocessing steps into a ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, columns_for_scaling),
        ('cat', categorical_transformer, columns_for_encoding)
    ]
)

# Combine the preprocessor into a Pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

# Fit and transform the data
df_processed = pipeline.fit_transform(df)

joblib.dump(pipeline, 'process_data.pkl')

X_train, X_test, y_train, y_test = train_test_split(df_processed, price_column, test_size=0.3, random_state=42)

# %%
X_train
# Out:
# array([[ 8.09025596e-01, -3.51095751e-01, -7.06355567e-01, ...,
#         -2.09771398e-03, -5.05992512e-03,  1.32458295e-03],
#        [-7.91068130e-01, -3.51095751e-01,  1.11940457e+00, ...,
#         -4.49008166e-04,  8.31075719e-04, -2.03080889e-03],
#        [ 8.09025596e-01, -9.89777471e-01, -9.77688554e-02, ...,
#          2.86636129e-04,  2.96889876e-03, -4.70932945e-03],
#        ...,
#        [-7.91068130e-01, -3.51095751e-01, -9.77688554e-02, ...,
#          3.30587562e-02,  1.64308749e-01, -1.63740733e-02],
#        [ 8.09025596e-01, -3.51095751e-01,  1.72799128e+00, ...,
#         -2.95592005e-02,  8.30604562e-02, -3.90200806e-02],
#        [-7.91068130e-01, -3.51095751e-01,  1.11940457e+00, ...,
#         -3.97200860e-03,  1.69350960e-03, -8.27288435e-04]])

# %%
#Define pipeline
pipeline = Pipeline(steps=[
    ('svr', SVR())
])

# %%
#Define hyperparameters of pipeline that need tuning and the range values of them
param_grid = {'svr__C': [10,20,50,100,200,300,400,500],  
              'svr__gamma': [0.001,0.01,0.1,1.0], 
              'svr__kernel': ['poly','rbf'],
              'svr__epsilon':[0.01,0.1,0.25,1.0,4.0,16.0,64.0,256.0],
             }

# %%
# Define the halving grid search with cross-validation
halving_grid_search = HalvingGridSearchCV(pipeline, param_grid, scoring="r2", cv=5, verbose=6, factor=3,error_score='raise')
halving_grid_search.fit(X_train, y_train)
# Out:
# n_iterations: 5
# n_required_iterations: 6
# n_possible_iterations: 5
# min_resources_: 88
# max_resources_: 21456
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 512
# n_resources: 88
# Fitting 5 folds for each of 512 candidates, totalling 2560 fits
# [CV 1/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.096, test=-0.049) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.114, test=-0.121) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.072, test=-0.048) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.101, test=-0.186) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.097, test=-0.081) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.290, test=0.396) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.223, test=-0.074) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.429, test=0.352) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.237, test=0.647) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.220, test=0.078) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.025, test=0.090) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.061, test=-0.107) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.047, test=0.027) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.055, test=-0.064) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.136, test=-0.073) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.701, test=0.822) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.538, test=-0.030) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.881, test=0.548) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.656, test=0.653) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.512, test=0.118) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=0.449) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=0.047) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=0.247) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=0.402) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=-0.072) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=1.000, test=0.716) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=1.000, test=-0.064) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=1.000, test=0.429) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.997, test=-0.275) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=1.000, test=0.396) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=0.449) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=0.047) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=0.247) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=0.402) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=-0.072) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=1.000, test=0.023) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=1.000, test=-0.084) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=1.000, test=-0.001) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=1.000, test=-0.146) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=1.000, test=0.011) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.092, test=-0.046) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.105, test=-0.119) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.078, test=-0.053) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.086, test=-0.127) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.085, test=-0.074) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.333, test=0.468) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.236, test=-0.067) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.438, test=0.353) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.262, test=0.696) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.211, test=0.063) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.016, test=0.096) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.043, test=-0.113) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.065, test=0.038) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.049, test=-0.043) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.149, test=-0.064) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.744, test=0.838) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.566, test=-0.018) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.880, test=0.451) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.691, test=0.496) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.540, test=0.156) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.991, test=0.460) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.993, test=0.027) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.984, test=0.347) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.995, test=0.360) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.995, test=-0.051) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.990, test=0.699) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.995, test=-0.064) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.985, test=0.412) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.993, test=-0.351) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.995, test=0.382) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.991, test=0.460) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.993, test=0.027) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.984, test=0.347) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.995, test=0.360) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.995, test=-0.051) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.990, test=0.019) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.993, test=-0.081) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.982, test=-0.019) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.994, test=-0.289) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.994, test=0.014) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.061, test=-0.028) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.070, test=-0.113) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.029, test=-0.011) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.078, test=-0.099) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.058, test=-0.059) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.349, test=0.469) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.255, test=-0.056) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.482, test=0.389) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.299, test=0.688) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.227, test=0.080) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.006, test=0.094) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.018, test=-0.108) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.088, test=0.048) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.035, test=-0.000) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.166, test=-0.052) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.770, test=0.824) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.613, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.834, test=0.378) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.696, test=0.421) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.572, test=0.210) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.947, test=0.474) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.965, test=0.005) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.910, test=0.365) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.973, test=0.199) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.973, test=-0.020) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.947, test=0.660) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.969, test=-0.060) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.918, test=0.377) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.972, test=-0.613) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.975, test=0.367) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.947, test=0.474) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.965, test=0.005) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.910, test=0.365) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.973, test=0.199) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.973, test=-0.020) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.937, test=0.003) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.960, test=-0.075) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.899, test=-0.084) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.965, test=-0.631) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.966, test=0.017) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.100, test=-0.095) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.015, test=-0.076) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.163, test=-0.327) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.046, test=-1.396) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.033, test=-0.000) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-0.044, test=0.101) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.094, test=-0.021) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-0.218, test=-0.615) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.113, test=-2.272) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.119, test=0.081) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.077, test=-0.039) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.003, test=-0.068) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.166, test=-0.376) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.029, test=-1.475) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.133, test=-0.001) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.265, test=0.507) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.374, test=0.012) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-0.100, test=-0.653) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.505, test=-2.593) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.369, test=0.174) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.188, test=0.204) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.428, test=-0.005) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-0.137, test=-0.729) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.549, test=-3.603) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.586, test=-0.075) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.169, test=0.038) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.493, test=-0.036) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-0.287, test=-1.022) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.579, test=-4.822) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.601, test=0.187) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.188, test=0.205) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.428, test=-0.005) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-0.138, test=-0.729) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.549, test=-3.604) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.586, test=-0.075) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.163, test=-0.368) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.454, test=-0.042) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-0.202, test=-1.060) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.501, test=-4.508) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.537, test=-0.035) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-5.930, test=-62.498) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-5.489, test=-1.689) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-6.495, test=-68.984) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-5.837, test=-1.807) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-5.977, test=-62.999) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-5.536, test=-1.722) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-6.494, test=-68.986) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-5.933, test=-1.849) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-6.458, test=-68.242) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-5.642, test=-1.805) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-6.411, test=-67.864) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-5.968, test=-1.856) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-6.458, test=-68.241) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-5.641, test=-1.805) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-6.292, test=-66.457) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-5.978, test=-1.879) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-3.588, test=-2.704) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-4.231, test=-0.001) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-3.356, test=-5.057) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-6.621, test=-69.283) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-6.945, test=-2.173) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.096, test=-0.049) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.114, test=-0.121) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.072, test=-0.048) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.101, test=-0.186) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.096, test=-0.081) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.379, test=0.490) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.311, test=-0.058) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.531, test=0.408) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.337, test=0.754) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.292, test=0.106) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.027, test=0.146) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.014, test=-0.100) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.129, test=0.079) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.015, test=0.036) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.168, test=-0.068) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.837, test=0.910) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.677, test=0.003) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.952, test=0.511) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.759, test=0.411) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.664, test=0.155) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=0.449) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=0.047) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=0.247) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=0.402) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=-0.072) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=1.000, test=0.716) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=1.000, test=-0.064) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=1.000, test=0.429) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=1.000, test=-0.332) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=1.000, test=0.396) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=0.449) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=0.047) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=0.247) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=0.402) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=-0.072) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=1.000, test=0.023) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=1.000, test=-0.084) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=1.000, test=-0.001) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=1.000, test=-0.146) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=1.000, test=0.011) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.092, test=-0.046) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.105, test=-0.119) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.078, test=-0.053) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.086, test=-0.127) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.084, test=-0.074) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.444, test=0.581) total time=   0.0s
# ...
# [CV 3/5] END svr__C=400, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.794, test=0.646) total time=   0.0s
# [CV 4/5] END svr__C=400, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.847, test=0.355) total time=   0.0s
# [CV 5/5] END svr__C=400, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.883, test=0.703) total time=   0.0s
# [CV 1/5] END svr__C=500, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.819, test=0.553) total time=   0.0s
# [CV 2/5] END svr__C=500, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.890, test=0.790) total time=   0.0s
# [CV 3/5] END svr__C=500, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.810, test=0.661) total time=   0.0s
# [CV 4/5] END svr__C=500, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.886, test=0.225) total time=   0.0s
# [CV 5/5] END svr__C=500, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.910, test=0.689) total time=   0.0s
# [CV 1/5] END svr__C=50, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.800, test=0.607) total time=   0.0s
# [CV 2/5] END svr__C=50, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.727, test=0.651) total time=   0.0s
# [CV 3/5] END svr__C=50, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.708, test=0.662) total time=   0.0s
# [CV 4/5] END svr__C=50, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.734, test=0.646) total time=   0.0s
# [CV 5/5] END svr__C=50, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.648, test=0.645) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.695, test=0.543) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.604, test=0.520) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.573, test=0.600) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.626, test=0.588) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.466, test=0.614) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.709, test=0.559) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.631, test=0.577) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.603, test=0.610) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.655, test=0.606) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.496, test=0.622) total time=   0.0s
# [CV 1/5] END svr__C=500, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.825, test=0.563) total time=   0.0s
# [CV 2/5] END svr__C=500, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.890, test=0.787) total time=   0.0s
# [CV 3/5] END svr__C=500, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.814, test=0.667) total time=   0.0s
# [CV 4/5] END svr__C=500, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.881, test=0.290) total time=   0.0s
# [CV 5/5] END svr__C=500, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.909, test=0.702) total time=   0.0s
# [CV 1/5] END svr__C=500, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.824, test=0.569) total time=   0.0s
# [CV 2/5] END svr__C=500, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.887, test=0.794) total time=   0.1s
# [CV 3/5] END svr__C=500, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.811, test=0.669) total time=   0.0s
# [CV 4/5] END svr__C=500, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.873, test=0.368) total time=   0.0s
# [CV 5/5] END svr__C=500, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.907, test=0.715) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.703, test=0.551) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.617, test=0.541) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.582, test=0.603) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.639, test=0.596) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.476, test=0.620) total time=   0.0s
# ----------
# iter: 3
# n_candidates: 19
# n_resources: 2376
# Fitting 5 folds for each of 19 candidates, totalling 95 fits
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.790, test=0.762) total time=   1.3s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.698, test=0.641) total time=   1.3s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.744, test=0.666) total time=   1.3s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 3
#       1 # Define the halving grid search with cross-validation
#       2 halving_grid_search = HalvingGridSearchCV(pipeline, param_grid, scoring="r2", cv=5, verbose=6, factor=3,error_score='raise')
# ----> 3 halving_grid_search.fit(X_train, y_train)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search_successive_halving.py:257, in BaseSuccessiveHalving.fit(self, X, y, groups, **fit_params)
#     249 self._check_input_parameters(
#     250     X=X,
#     251     y=y,
#     252     groups=groups,
#     253 )
#     255 self._n_samples_orig = _num_samples(X)
# --> 257 super().fit(X, y=y, groups=groups, **fit_params)
#     259 # Set best_score_: BaseSearchCV does not set it, as refit is a callable
#     260 self.best_score_ = self.cv_results_["mean_test_score"][self.best_index_]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search_successive_halving.py:361, in BaseSuccessiveHalving._run_search(self, evaluate_candidates)
#     354     cv = self._checked_cv_orig
#     356 more_results = {
#     357     "iter": [itr] * n_candidates,
#     358     "n_resources": [n_resources] * n_candidates,
#     359 }
# --> 361 results = evaluate_candidates(
#     362     candidate_params, cv, more_results=more_results
#     363 )
#     365 n_candidates_to_keep = ceil(n_candidates / self.factor)
#     366 candidate_params = _top_k(results, n_candidates_to_keep, itr)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:729, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     727         estimator.fit(X_train, **fit_params)
#     728     else:
# --> 729         estimator.fit(X_train, y_train, **fit_params)
#     731 except Exception:
#     732     # Note fit time as time until error
#     733     fit_time = time.time() - start_time
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\pipeline.py:427, in Pipeline.fit(self, X, y, **fit_params)
#     425     if self._final_estimator != "passthrough":
#     426         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 427         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     429 return self
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:250, in BaseLibSVM.fit(self, X, y, sample_weight)
#     247     print("[LibSVM]", end="")
#     249 seed = rnd.randint(np.iinfo("i").max)
# --> 250 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     251 # see comment on the other call to np.iinfo in this file
#     253 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:329, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     315 libsvm.set_verbosity_wrap(self.verbose)
#     317 # we don't pass **self.get_params() to allow subclasses to
#     318 # add other parameters to __init__
#     319 (
#     320     self.support_,
#     321     self.support_vectors_,
#     322     self._n_support,
#     323     self.dual_coef_,
#     324     self.intercept_,
#     325     self._probA,
#     326     self._probB,
#     327     self.fit_status_,
#     328     self._num_iter,
# --> 329 ) = libsvm.fit(
#     330     X,
#     331     y,
#     332     svm_type=solver_type,
#     333     sample_weight=sample_weight,
#     334     # TODO(1.4): Replace "_class_weight" with "class_weight_"
#     335     class_weight=getattr(self, "_class_weight", np.empty(0)),
#     336     kernel=kernel,
#     337     C=self.C,
#     338     nu=self.nu,
#     339     probability=self.probability,
#     340     degree=self.degree,
#     341     shrinking=self.shrinking,
#     342     tol=self.tol,
#     343     cache_size=self.cache_size,
#     344     coef0=self.coef0,
#     345     gamma=self._gamma,
#     346     epsilon=self.epsilon,
#     347     max_iter=self.max_iter,
#     348     random_seed=random_seed,
#     349 )
#     351 self._warn_from_fit_status()
#
# File sklearn\svm\_libsvm.pyx:265, in sklearn.svm._libsvm.fit()
#
# KeyboardInterrupt:

# %%
best_params = halving_grid_search.best_params_
best_model = halving_grid_search.best_estimator_
best_score = halving_grid_search.best_score_

# %%
# Save the best model
joblib_file = "best_model.joblib"
joblib.dump(best_model, joblib_file)
print(f"Model saved to {joblib_file}")

# Load the model from the file
loaded_model = joblib.load(joblib_file)
# Out:
# Model saved to best_model.joblib

# %%
y_pred = loaded_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Best parameters: {best_params}")
print(f"Best scores: {best_score}")
print(f"Test MSE: {mse}")
print(f"Model score: {best_model.score(X_test, y_test)}")
# Out:
# Best parameters: {'svr__C': 20, 'svr__epsilon': 0.01, 'svr__gamma': 0.1, 'svr__kernel': 'rbf'}
# Best scores: 0.8639279857761399
# Test MSE: 0.6157878085505033
# Model score: 0.851871086940417
